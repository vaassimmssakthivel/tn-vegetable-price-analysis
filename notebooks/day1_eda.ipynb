# %% [markdown]
# ## FIRST CELL

# %%
import pandas as pd

# %% [markdown]
# ## LOAD DATASET

# %%
df = pd.read_csv("../data/Raw/TN_Vegetable_Price_Index_Enhanced.csv")

# %% [markdown]
# ## VERIFY DATA LOADED

# %%
df.head()
# Out:
#       record_id         farmer_name       vegetable_name category  \
# 0  TN-VEG-00001        Velu Pandian  Manathakkali Keerai    Leafy
# 1  TN-VEG-00002      Murugan Pillai           Lotus Stem  Aquatic
# 2  TN-VEG-00003     Durai Murugesan            Drumstick      Pod
# 3  TN-VEG-00004      Suresh Karthik            Ash Gourd    Gourd
# 4  TN-VEG-00005  Kannan Subramanian        Banana Flower   Flower
#
#        district          mandi_name        date             season  month  \
# 0      Nilgiris    Ooty Hill Market  2022-01-31             Winter      1
# 1  Nagapattinam   Coastal Mandi NGP  2023-09-15  Southwest Monsoon      9
# 2      Dindigul       Palani Market  2024-02-25             Winter      2
# 3       Madurai  Mattuthavani Mandi  2022-02-12             Winter      2
# 4      Nilgiris    Ooty Hill Market  2021-07-27  Southwest Monsoon      7
#
#    year  ...  env_stress_index  mom_price_change_pct  \
# 0  2022  ...             -1.29                 25.56
# 1  2023  ...              9.44                 23.71
# 2  2024  ...             -7.27                -10.29
# 3  2022  ...             -3.93                113.07
# 4  2021  ...             16.20                -38.15
#
#    seasonal_price_premium_pct  cumul_revenue_per_farmer retail_price_bin  \
# 0                      2.1782               23515273.22            60-80
# 1                     10.8862               38707643.06             >100
# 2                    -14.9507               42246756.07           80-100
# 3                     25.2591               23316277.74            40-60
# 4                     -8.2327               17234230.95            60-80
#
#   district_avg_retail district_price_rank veg_price_skewness  \
# 0              101.95                   9             0.6381
# 1              103.78                  14             0.7657
# 2              102.41                  11             0.5516
# 3              105.18                  17             0.4942
# 4              101.95                   9             0.5197
#
#   veg_price_kurtosis  organic_price_premium_inr
# 0             0.2379                        0.0
# 1             0.4030                        0.0
# 2             0.1479                        0.0
# 3             0.1230                        0.0
# 4            -0.0460                        0.0
#
# [5 rows x 74 columns]

# %% [markdown]
# ## UNDERSTAND DATASET STRUCTURE

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11000 entries, 0 to 10999
# Data columns (total 74 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   record_id                   11000 non-null  object
#  1   farmer_name                 11000 non-null  object
#  2   vegetable_name              11000 non-null  object
#  3   category                    11000 non-null  object
#  4   district                    11000 non-null  object
#  5   mandi_name                  11000 non-null  object
#  6   date                        11000 non-null  object
#  7   season                      11000 non-null  object
#  8   month                       11000 non-null  int64
#  9   year                        11000 non-null  int64
#  10  farm_price_inr_per_kg       11000 non-null  float64
#  11  wholesale_price_inr_per_kg  11000 non-null  float64
#  12  retail_price_inr_per_kg     11000 non-null  float64
#  13  quantity_kg                 11000 non-null  float64
#  14  quality_grade               11000 non-null  object
#  15  organic                     11000 non-null  object
#  16  market_type                 11000 non-null  object
#  17  storage_type                11000 non-null  object
#  18  transport_mode              11000 non-null  object
#  19  transport_distance_km       11000 non-null  float64
#  20  transport_cost_inr          11000 non-null  float64
#  21  shelf_life_days             11000 non-null  int64
#  22  humidity_pct                11000 non-null  float64
#  23  temperature_c               11000 non-null  float64
#  24  rainfall_mm                 11000 non-null  float64
#  25  post_harvest_loss_pct       11000 non-null  float64
#  26  markup_farm_to_retail_pct   11000 non-null  float64
#  27  payment_mode                11000 non-null  object
#  28  gst_rate_pct                11000 non-null  float64
#  29  cold_chain_used             11000 non-null  object
#  30  govt_scheme                 8806 non-null   object
#  31  fpo_member                  11000 non-null  object
#  32  soil_type                   11000 non-null  object
#  33  irrigation_type             9220 non-null   object
#  34  total_revenue_inr           11000 non-null  float64
#  35  gross_margin_inr_per_kg     11000 non-null  float64
#  36  transport_cost_per_kg       11000 non-null  float64
#  37  net_margin_inr_per_kg       11000 non-null  float64
#  38  farmer_profit_inr           11000 non-null  float64
#  39  price_spread_inr            11000 non-null  float64
#  40  ws_to_farm_ratio            11000 non-null  float64
#  41  retail_to_ws_ratio          11000 non-null  float64
#  42  log_farm_price              11000 non-null  float64
#  43  log_retail_price            11000 non-null  float64
#  44  log_quantity                11000 non-null  float64
#  45  z_score_farm_price          11000 non-null  float64
#  46  z_score_retail_price        11000 non-null  float64
#  47  z_score_quantity            11000 non-null  float64
#  48  farm_price_pctile_rank      11000 non-null  float64
#  49  retail_price_pctile_rank    11000 non-null  float64
#  50  rolling_30d_avg_retail      11000 non-null  float64
#  51  rolling_30d_std_retail      11000 non-null  float64
#  52  rolling_7d_avg_retail       11000 non-null  float64
#  53  farm_price_outlier_flag     11000 non-null  int64
#  54  retail_price_outlier_flag   11000 non-null  int64
#  55  price_cv_pct                11000 non-null  float64
#  56  normalized_farm_price       11000 non-null  float64
#  57  normalized_retail_price     11000 non-null  float64
#  58  phl_adjusted_revenue_inr    11000 non-null  float64
#  59  phl_value_lost_inr          11000 non-null  float64
#  60  transport_efficiency_score  11000 non-null  float64
#  61  demand_supply_proxy         11000 non-null  float64
#  62  quality_score_numeric       11000 non-null  int64
#  63  weighted_revenue            11000 non-null  float64
#  64  env_stress_index            11000 non-null  float64
#  65  mom_price_change_pct        11000 non-null  float64
#  66  seasonal_price_premium_pct  11000 non-null  float64
#  67  cumul_revenue_per_farmer    11000 non-null  float64
#  68  retail_price_bin            11000 non-null  object
#  69  district_avg_retail         11000 non-null  float64
#  70  district_price_rank         11000 non-null  int64
#  71  veg_price_skewness          11000 non-null  float64
#  72  veg_price_kurtosis          11000 non-null  float64
#  73  organic_price_premium_inr   11000 non-null  float64
# dtypes: float64(47), int64(7), object(20)
# memory usage: 6.2+ MB

# %% [markdown]
# ## STATISTICAL SUMMARY

# %%
df.describe()
# Out:
#               month          year  farm_price_inr_per_kg  \
# count  11000.000000  11000.000000           11000.000000
# mean       6.481273   2021.504000              36.906908
# std        3.487410      1.708554              24.755100
# min        1.000000   2019.000000               5.800000
# 25%        3.000000   2020.000000              20.740000
# 50%        7.000000   2022.000000              29.920000
# 75%       10.000000   2023.000000              45.687500
# max       12.000000   2024.000000             179.880000
#
#        wholesale_price_inr_per_kg  retail_price_inr_per_kg   quantity_kg  \
# count                11000.000000             11000.000000  11000.000000
# mean                    59.049188               103.204565   1021.161109
# std                     40.030688                71.079084    565.912928
# min                      8.470000                12.990000     50.100000
# 25%                     32.727500                56.567500    527.700000
# 50%                     47.635000                83.480000   1020.500000
# 75%                     73.495000               127.722500   1507.725000
# max                    320.530000               608.870000   1999.700000
#
#        transport_distance_km  transport_cost_inr  shelf_life_days  \
# count           11000.000000        11000.000000     11000.000000
# mean              306.027327         1683.092297        11.467273
# std               169.442282         1013.514422         5.789314
# min                10.000000           38.920000         2.000000
# 25%               159.500000          837.405000         6.000000
# 50%               306.500000         1606.555000        11.000000
# 75%               453.000000         2401.622500        16.000000
# max               599.900000         4466.610000        21.000000
#
#        humidity_pct  ...  weighted_revenue  env_stress_index  \
# count  11000.000000  ...      1.100000e+04      11000.000000
# mean      69.005791  ...      2.618232e+05          8.810716
# std       14.133159  ...      3.049541e+05          9.765761
# min       40.000000  ...      2.262860e+03        -11.300000
# 25%       60.200000  ...      7.277326e+04          0.507500
# 50%       69.000000  ...      1.635027e+05          8.320000
# 75%       79.700000  ...      3.322843e+05         15.922500
# max       95.000000  ...      4.210140e+06         37.460000
#
#        mom_price_change_pct  seasonal_price_premium_pct  \
# count          11000.000000                1.100000e+04
# mean               2.996535                1.636364e-07
# std               25.491853                2.112431e+01
# min              -54.560000               -4.917890e+01
# 25%              -15.332500               -1.560225e+01
# 50%                0.100000               -2.514600e+00
# 75%               17.892500                1.324345e+01
# max              154.380000                8.939830e+01
#
#        cumul_revenue_per_farmer  district_avg_retail  district_price_rank  \
# count              1.100000e+04         11000.000000         11000.000000
# mean               2.334897e+07           103.203735            12.895364
# std                1.353893e+07             4.165159             7.155950
# min                4.979100e+03            95.130000             1.000000
# 25%                1.163582e+07            99.790000             7.000000
# 50%                2.315318e+07           103.320000            13.000000
# 75%                3.484646e+07           105.740000            19.000000
# max                5.335177e+07           111.930000            25.000000
#
#        veg_price_skewness  veg_price_kurtosis  organic_price_premium_inr
# count        11000.000000        11000.000000                    11000.0
# mean             0.579788            0.164172                        0.0
# std              0.154168            0.431723                        0.0
# min              0.237000           -0.576700                        0.0
# 25%              0.494200           -0.130300                        0.0
# 50%              0.537200            0.060700                        0.0
# 75%              0.710700            0.439400                        0.0
# max              0.989800            1.599900                        0.0
#
# [8 rows x 54 columns]

# %% [markdown]
# CHECK MISSING VALUES

# %%
df.isnull().sum()
# Out:
# record_id                    0
# farmer_name                  0
# vegetable_name               0
# category                     0
# district                     0
#                             ..
# district_avg_retail          0
# district_price_rank          0
# veg_price_skewness           0
# veg_price_kurtosis           0
# organic_price_premium_inr    0
# Length: 74, dtype: int64

# %% [markdown]
# ## FIRST REAL ANALYSIS

# %% [markdown]
# # Average prices by district

# %%
df.groupby('district')['retail_price_inr_per_kg'].mean()
# Out:
# district
# Chennai          95.127354
# Coimbatore      110.130786
# Cuddalore       111.933624
# Dharmapuri      104.408192
# Dindigul        102.414289
# Erode            96.178164
# Kancheepuram    106.504018
# Karur           101.998850
# Krishnagiri      99.790189
# Madurai         105.184597
# Nagapattinam    103.779572
# Namakkal        108.853657
# Nilgiris        101.952745
# Pudukkottai     105.340137
# Salem            97.754365
# Sivagangai      105.736406
# Thanjavur       104.514963
# Theni           103.317598
# Thoothukudi     106.600618
# Tirunelveli     101.547929
# Tiruvarur        99.281843
# Trichy          102.502237
# Vellore         108.686620
# Villupuram       98.989011
# Virudhunagar     98.933767
# Name: retail_price_inr_per_kg, dtype: float64

# %% [markdown]
# # Sorts districts:highest price → lowest price.

# %%
df.groupby('district')['retail_price_inr_per_kg'].mean().sort_values(ascending=False)
# Out:
# district
# Cuddalore       111.933624
# Coimbatore      110.130786
# Namakkal        108.853657
# Vellore         108.686620
# Thoothukudi     106.600618
# Kancheepuram    106.504018
# Sivagangai      105.736406
# Pudukkottai     105.340137
# Madurai         105.184597
# Thanjavur       104.514963
# Dharmapuri      104.408192
# Nagapattinam    103.779572
# Theni           103.317598
# Trichy          102.502237
# Dindigul        102.414289
# Karur           101.998850
# Nilgiris        101.952745
# Tirunelveli     101.547929
# Krishnagiri      99.790189
# Tiruvarur        99.281843
# Villupuram       98.989011
# Virudhunagar     98.933767
# Salem            97.754365
# Erode            96.178164
# Chennai          95.127354
# Name: retail_price_inr_per_kg, dtype: float64

# %% [markdown]
# ## SEASONAL ANALYSIS

# %% [markdown]
# # Which season has highest average retail price?

# %%
df.groupby('season')['retail_price_inr_per_kg'].mean()
# Out:
# season
# Northeast Monsoon     89.874312
# Southwest Monsoon    104.471418
# Summer               121.901248
# Winter                94.006837
# Name: retail_price_inr_per_kg, dtype: float64

# %% [markdown]
# ## TRANSPORT COST ANALYSIS

# %% [markdown]
# # Which transport mode is most expensive?

# %%
df.groupby('transport_mode')['transport_cost_inr'].mean()
# Out:
# transport_mode
# Auto          1666.879717
# Bike          1691.395569
# Mini-Truck    1687.130130
# Tempo         1659.063024
# Train         1669.604227
# Truck         1723.657450
# Name: transport_cost_inr, dtype: float64

# %% [markdown]
# ## CREATE FIRST CHART

# %%
import matplotlib.pyplot as plt

# %%
district_price = (
    df.groupby('district')['retail_price_inr_per_kg']
    .mean()
    .sort_values(ascending=False)
)

district_price.plot(kind='bar')

plt.title("Average Retail Price by District")

plt.ylabel("Retail Price")

plt.show()

# %% [markdown]
# # SAVE CHART

# %%
plt.savefig("../images/district_price_chart.png")

# %% [markdown]
# # Key Findings
#
# 1. Chennai has higher average retail prices.
# 2. Summer season shows increased pricing.
# 3. Certain transport modes increase costs significantly.
